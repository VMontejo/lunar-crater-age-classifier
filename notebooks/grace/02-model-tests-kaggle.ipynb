# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-0901.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M158891067RC_pyr-0868.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1113517233LC_pyr-0452.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-1141.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M158891067RC_pyr-0986.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-0789.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0025.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-0319.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0996.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-0680.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0582.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M158891067RC_pyr-0617.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M158891067RC_pyr-0149.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0106.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-1138.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0089.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0006.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-1381.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1113517233LC_pyr-0165.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0123.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0322.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-0073.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M105422456RC_pyr-0335.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-1115.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M143730132RC_pyr-0182.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0328.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-0547.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-1125.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0469.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-1788.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0381.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0031.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-0614.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0451.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0620.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-1107.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-1434.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0198.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-1324.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-1235.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-1011.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0082.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-1604.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M158891067RC_pyr-0916.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0089.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-1776.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1181351902LC_pyr-1714.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1164581744RC_pyr-0282.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M143730132RC_pyr-0249.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1160547140LC_pyr-0952.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1113517233LC_pyr-0411.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0151.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M1211877309LC_pyr-0501.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M176629149LC_pyr-0119.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/ejecta/M158891067RC_pyr-0204.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0375.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M143730132RC_pyr-0299.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0604.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1204549897LC_pyr-1751.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0353.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0699.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1030.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117624662LC_pyr-0075.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0750.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M143730132RC_pyr-0976.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1262.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0436.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117624662LC_pyr-0231.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0498.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-2075.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1874.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0396.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M179872247RC_pyr-0352.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0221.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0255.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-1520.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1204549897LC_pyr-1355.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1113517233LC_pyr-0317.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0735.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1201607242RC_pyr-1106.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0665.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0966.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1211877309LC_pyr-0456.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-2200.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0703.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0519.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1134.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1182.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0090.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0300.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0460.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1204549897LC_pyr-1596.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1164581744RC_pyr-0982.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0911.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1657.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-1024.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1239.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0205.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0622.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0317.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-1040.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-1280.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1201607242RC_pyr-0813.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1123.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0203.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-2035.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-1902.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0488.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1160547140LC_pyr-1564.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0109.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0847.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0625.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0156.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0931.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0654.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0833.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1211877309LC_pyr-0476.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1170.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M176629149LC_pyr-0960.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0302.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0718.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1684.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-2074.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M176629149LC_pyr-0045.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1160547140LC_pyr-0260.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0657.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1113517233LC_pyr-0088.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0339.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0432.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0048.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0743.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0143.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1201607242RC_pyr-0800.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0884.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0661.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0734.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-1077.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1113517233LC_pyr-0047.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M105422456RC_pyr-0755.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0208.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M176629149LC_pyr-0233.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-1795.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-2189.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117624662LC_pyr-0194.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-2191.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1932.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0313.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1164581744RC_pyr-1172.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M105422456RC_pyr-0083.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1761.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-2108.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-1916.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-0545.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0759.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1201607242RC_pyr-0921.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1204549897LC_pyr-1749.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0500.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0830.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1424.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-1221.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-0232.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-2022.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1181351902LC_pyr-0822.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1164581744RC_pyr-0481.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1833.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M105422456RC_pyr-0784.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-2183.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M158891067RC_pyr-0110.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1592.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1170504189RC_pyr-1006.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1160547140LC_pyr-0669.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M117358581LC_pyr-1682.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/oldcrater/M1160547140LC_pyr-0667.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1817.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2205.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0463.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0463.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2110.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2059.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1289.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1392.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0259.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0451.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1081.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0674.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0220.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0923.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-1169.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0125.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0836.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1321.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1760.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0947.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0244.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0744.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0192.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0998.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0095.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0599.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0849.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1118.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0819.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0267.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1367.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1113517233LC_pyr-0048.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1775.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0038.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0063.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1006.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0691.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0584.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2229.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1215.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1368.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0783.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0446.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0885.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1904.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0881.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0530.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0523.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0277.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1255.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0796.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1142.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1925.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0558.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0359.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0812.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1136.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0572.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1303.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0592.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1549.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1685.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1134.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1016.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0169.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1347.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1345.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-1064.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-2018.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1686.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0030.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M179872247RC_pyr-0357.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0734.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0090.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0151.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0057.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1459.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0293.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0313.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0679.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-2067.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1607.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0287.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0047.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0797.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117624662LC_pyr-0219.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0216.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1964.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1145.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0417.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0518.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1305.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1539.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0517.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0118.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0292.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0387.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1196.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0572.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0657.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0611.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0957.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-1083.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1467.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1113517233LC_pyr-0315.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0383.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1211877309LC_pyr-0587.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0213.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1413.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0348.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2455.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0046.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1856.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0835.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0347.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0707.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0584.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0350.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0440.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0778.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1421.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1344.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0971.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0946.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0281.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0578.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0815.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1263.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0369.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117624662LC_pyr-0094.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1211877309LC_pyr-0007.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1068.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0992.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1781.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M179872247RC_pyr-0440.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0362.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0765.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0708.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0309.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0347.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0491.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1462.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0011.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1281.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1018.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0603.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1406.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0037.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1488.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0203.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0776.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-1005.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1172.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1764.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0981.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0022.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0469.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-1023.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0567.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0235.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1825.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M179872247RC_pyr-0080.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1682.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0815.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1559.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M179872247RC_pyr-0119.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0184.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0745.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0148.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0825.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2163.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0416.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0739.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0852.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0044.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0682.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0763.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1390.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1516.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0546.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0489.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0428.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1819.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0184.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1147.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0601.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0100.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1341.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0908.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0859.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0728.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117624662LC_pyr-0236.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1544.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1671.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2098.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0556.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117624662LC_pyr-0060.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1874.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1541.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1413.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0073.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1191.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0751.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0185.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0490.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1756.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0516.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0873.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0895.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0984.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0328.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2060.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0835.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2104.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1831.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0988.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-0871.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1677.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1950.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0685.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M179872247RC_pyr-0094.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0484.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1020.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1113517233LC_pyr-0148.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1346.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1132.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1944.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0608.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117624662LC_pyr-0178.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0781.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0847.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1113517233LC_pyr-0237.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2458.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1294.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0322.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0540.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0169.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0270.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0961.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0020.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0838.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0131.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0384.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1423.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0422.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0199.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0224.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0445.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1242.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1431.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0222.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0072.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2097.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0986.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0388.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2028.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0589.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1211877309LC_pyr-0389.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0397.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-1012.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0632.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0276.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0120.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1575.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0647.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0130.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0649.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0810.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0137.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1568.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0831.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1878.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0430.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-2076.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-1200.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-1586.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0741.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1211877309LC_pyr-0590.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0154.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0201.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-0604.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M179872247RC_pyr-0145.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0628.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1927.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M176629149LC_pyr-0675.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0119.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0129.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0700.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1212.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-0685.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0458.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0764.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1272.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M143730132RC_pyr-0533.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M158891067RC_pyr-0669.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1181351902LC_pyr-1392.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0251.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0391.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1164581744RC_pyr-0078.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-1296.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1160547140LC_pyr-0447.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1170504189RC_pyr-1108.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M105422456RC_pyr-0839.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M117358581LC_pyr-2161.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1201607242RC_pyr-0210.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/val/none/M1204549897LC_pyr-0663.jpg
# ...
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-1215.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1145560677RC_pyr-1073.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1127776551RC_pyr-0298.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1178246048RC_pyr-0541.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1165350771RC_pyr-0716.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1126624503LC_pyr-1369.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-1988.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1157756910LC_pyr-2015.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-0055.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-2846.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1111784848LC_pyr-0183.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-1473.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1203713442RC_pyr-0198.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1185799204LC_pyr-1223.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-2771.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-3049.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1095437275RC_pyr-0868.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M114422988LC_pyr-0410.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-3270.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1126624503LC_pyr-1276.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-0176.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1205696659LC_pyr-0531.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1111784848LC_pyr-0211.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-0955.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1178388248LC_pyr-0146.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M143668575RC_pyr-1922.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-0762.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1178352512RC_pyr-0567.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1154769635LC_pyr-0910.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1119271697RC_pyr-0082.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-2370.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1115790663RC_pyr-0843.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M166650072LC_pyr-0055.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-0988.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M159705621LC_pyr-0736.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1157756910LC_pyr-0979.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1119271697RC_pyr-0374.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-1731.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1178388248LC_pyr-0692.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-0944.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1157756910LC_pyr-0817.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M157867349LC_pyr-1826.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1120065717LC_pyr-0056.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M158278493LC_pyr-1381.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1188367685RC_pyr-0443.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1185799204LC_pyr-0994.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1116046457RC_pyr-0661.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M186905826RC_pyr-0145.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1185799204LC_pyr-0715.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1157756910LC_pyr-3890.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-2324.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-0895.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1107946137RC_pyr-0366.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-2260.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1134431770LC_pyr-0388.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-3359.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-0875.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1127776551RC_pyr-0156.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-0231.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1112607320LC_pyr-0356.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1111784848LC_pyr-1606.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1148335313RC_pyr-0510.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1127711168RC_pyr-0286.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119333256LC_pyr-1428.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-3175.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1106595881LC_pyr-1062.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M114422988LC_pyr-0816.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-1360.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-2247.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-1350.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1205696659LC_pyr-0307.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M143668575RC_pyr-3502.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1129013526RC_pyr-0504.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1148335313RC_pyr-1174.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M187283366RC_pyr-0697.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-1172.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M152228223RC_pyr-0447.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119787593RC_pyr-0266.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M158278493LC_pyr-0973.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1097014591RC_pyr-0152.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1126624503LC_pyr-1586.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1183253578RC_pyr-1598.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-1098.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1188367685RC_pyr-0424.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1102603360LC_pyr-0035.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-2059.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1154769635LC_pyr-1169.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1205696659LC_pyr-0995.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M144721936LC_pyr-0067.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1148335313RC_pyr-1285.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-3031.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119333256LC_pyr-0810.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-1381.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M143668575RC_pyr-3354.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-1370.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1157756910LC_pyr-3352.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119787593RC_pyr-1041.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M107280100RC_pyr-0229.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M114422988LC_pyr-2027.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1119271697RC_pyr-0411.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1194737528LC_pyr-0220.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1154769635LC_pyr-0200.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M186905826RC_pyr-1024.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M171679982RC_pyr-0395.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M191761375RC_pyr-0060.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1111784848LC_pyr-1275.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1183253578RC_pyr-1525.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1183253578RC_pyr-3303.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M157867349LC_pyr-1790.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M166650072LC_pyr-1688.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1186553935LC_pyr-0027.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1157756910LC_pyr-3340.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M114422988LC_pyr-1514.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1178246048RC_pyr-0863.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M187283366RC_pyr-1407.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1097772847RC_pyr-0015.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M166650072LC_pyr-1502.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-0966.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M158278493LC_pyr-1509.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M158278493LC_pyr-2404.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1126624503LC_pyr-1624.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-0631.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1203016739RC_pyr-0190.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1120065717LC_pyr-0451.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-1481.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1185799204LC_pyr-1659.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1119271697RC_pyr-0460.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M155294851LC_pyr-0579.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1115790663RC_pyr-0337.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1119271697RC_pyr-2445.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119333256LC_pyr-1506.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-1154.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M107280100RC_pyr-0351.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1107946137RC_pyr-0721.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-1446.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1115790663RC_pyr-0442.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1107946137RC_pyr-0337.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M148563970RC_pyr-2613.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119333256LC_pyr-2126.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M191631763RC_pyr-0847.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M157867349LC_pyr-1607.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1167362364RC_pyr-1505.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M115441101LC_pyr-1358.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1193295832LC_pyr-0021.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-0818.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M119217559LC_pyr-0302.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M180665045RC_pyr-3015.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1127711168RC_pyr-0367.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1127776551RC_pyr-0605.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1095437275RC_pyr-0562.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1178388248LC_pyr-1387.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M166650072LC_pyr-0546.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1127776551RC_pyr-0944.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M155294851LC_pyr-0270.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M115441101LC_pyr-0850.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M141812337RC_pyr-0338.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M113855094RC_pyr-0309.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M1203713442RC_pyr-0159.jpg
# /kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data/train/none/M134762799RC_pyr-0176.jpg

# %% [markdown]
# ## Image loading and preprocess

# %%
import os
import glob
import numpy as np
import tensorflow as tf

# Update BASE_DIR to match Kaggle dataset location
BASE_DIR = "/kaggle/input/lro-imagery-for-lrocnet-moon-classifier/raw_data" 
CLASS_NAMES = ["ejecta", "oldcrater", "none"]
N_CLASSES = len(CLASS_NAMES)
TARGET_SIZE = (227, 227)
IMAGE_EXT = "*.jpg"

# %%
# Define the target image size and number of classes based on EDA
def load_and_preprocess_image(file_path, class_label):
    """
    Loads an image from a file path, resizes it, scales pixel values,
    and returns the image tensor and one-hot encoded label.

    Args:
        file_path (tf.Tensor): Tensor containing the image file path (string).
        class_label (tf.Tensor): Tensor containing the integer class label (0, 1, or 2).

    Returns:
        tuple: (preprocessed_image_tensor, one_hot_label_tensor)
    """
    # 1. Load the raw image file as a binary string
    image_raw = tf.io.read_file(file_path)

    # 2. Decode the image
    # The image is decoded as a 3-channel (RGB) tensor of type uint8
    image = tf.image.decode_jpeg(image_raw, channels=3)

    # 3. Resize and convert to float (VGG input requirement)
    image = tf.image.resize(image, TARGET_SIZE)

    # 4. Normalize Pixel Values (0-255 to 0-1)
    image = tf.cast(image, tf.float32) / 255.0

    # 5. One-Hot Encode the Label
    # Converts the integer label (0, 1, or 2) into a vector (e.g., 0 -> [1, 0, 0])
    label = tf.one_hot(class_label, depth=N_CLASSES)

    return image, label

# %%
# --- Dataset Creation Function (The Pipeline) ---
def create_dataset(data_set, batch_size=32, cache=False, shuffle=False):
    """
    Creates a high-performance tf.data.Dataset pipeline for a given set.
    """

    # 1. Collect File Paths and Labels
    all_filepaths = []
    all_labels = []

    for label_index, class_name in enumerate(CLASS_NAMES):
        class_path = os.path.join(BASE_DIR, data_set, class_name)
        filepaths = glob.glob(os.path.join(class_path, IMAGE_EXT))
        all_filepaths.extend(filepaths)
        all_labels.extend([label_index] * len(filepaths))

    # Convert paths and labels to TensorFlow Datasets
    path_dataset = tf.data.Dataset.from_tensor_slices(all_filepaths)
    label_dataset = tf.data.Dataset.from_tensor_slices(all_labels)
    dataset = tf.data.Dataset.zip((path_dataset, label_dataset))

    # 2. Caching (Use if data fits in memory; speeds up repeated epochs)
    if cache:
        # Caching the data *after* the heavy loading/preprocessing step.
        dataset = dataset.cache()

    # 3. Shuffling (Only for the training set)
    if shuffle:
        # Buffer size should be large, e.g., the size of the training set or more
        dataset = dataset.shuffle(buffer_size=len(all_filepaths) * 2)

    # 4. Mapping (The core image loading, with parallelization)
    # tf.data.AUTOTUNE allows TensorFlow to select optimal thread count dynamically
    dataset = dataset.map(load_and_preprocess_image,
                          num_parallel_calls=tf.data.AUTOTUNE)

    # 5. Batching and prefetching (Performance optimization)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset, len(all_filepaths)

# %%
# --- Execution ---
# Generate the datasets for use in model.fit()
BATCH_SIZE = 16
# Cache is recommended for the training set if your computer has sufficient RAM
train_set, train_count = create_dataset("train", batch_size=BATCH_SIZE, shuffle=True, cache=True)
val_set, val_count = create_dataset("val", batch_size=BATCH_SIZE)
test_set, test_count = create_dataset("test", batch_size=BATCH_SIZE)

print(f"\nTraining Dataset (Cached, Shuffled): {train_count} files")
print(f"Validation Dataset: {val_count} files")
print(f"Test Dataset: {test_count} files")

# --- Verification of Batch Shapes ---

# Use .take(1) to get the first batch, and iter() to convert it to a Python iterable
# Note: TensorFlow's API for getting shapes from a batched dataset often requires iterating once.
first_train_batch = next(iter(train_set.take(1)))
train_image_batch, train_label_batch = first_train_batch

print("\n--- First Batch Shape Verification ---")
print(f"Training Batch Size (Max): {train_image_batch.shape[0]}")
print(f"Image Batch Shape: {train_image_batch.shape}")
print(f"Label Batch Shape: {train_label_batch.shape}")
print(f"Image Dtype: {train_image_batch.dtype}")
print(f"Label Dtype: {train_label_batch.dtype}")
# Out:
# Training Dataset (Cached, Shuffled): 3608 files
# Validation Dataset: 613 files
# Test Dataset: 779 files
#
# --- First Batch Shape Verification ---
# Training Batch Size (Max): 16
# Image Batch Shape: (16, 227, 227, 3)
# Label Batch Shape: (16, 3)
# Image Dtype: <dtype: 'float32'>
# Label Dtype: <dtype: 'float32'>

# %% [markdown]
# ## Define and freeze base model

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Nadam

# --- Constants from EDA ---
TARGET_INPUT_SHAPE = (227, 227, 3) # (Height, Width, Channels)
N_CLASSES = 3

# 1. Load the pre-trained VGG16 base model
# weights='imagenet' loads the pre-trained weights
# include_top=False discards the original classification layer
vgg16_base = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=TARGET_INPUT_SHAPE
)

# 2. Freeze the base layers (Transfer Learning Core Principle)
# We prevent the ImageNet-learned feature detectors from being damaged
# by large gradients during the initial, random-headed training phase.
for layer in vgg16_base.layers:
    layer.trainable = False

# %% [markdown]
# ## Build the new classification head

# %%
# Create the new classification head (Top of the network)
x = vgg16_base.output

# Global Average Pooling: Efficiently reduces the output of the convolutional
# layers to a flat vector, ready for the Dense layers.
x = GlobalAveragePooling2D(name='global_avg_pool')(x)

# Dense layer for feature refinement, using regularization
x = Dense(128, activation='relu', name='fc_head_1')(x)
x = tf.keras.layers.Dropout(0.5, name='dropout_1')(x)

# Final output layer: 3 units for the 3 classes, using Softmax for probabilities
predictions = Dense(N_CLASSES, activation='softmax', name='predictions')(x)

# --- 3. Create the Final Model ---
model = Model(inputs=vgg16_base.input, outputs=predictions)

# 4. Compile the Model
model.compile(
    optimizer=Nadam(learning_rate=3e-3),
    loss='categorical_crossentropy', # Used with one-hot encoded labels
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 227, 227, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 227, 227, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 227, 227, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 113, 113, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 113, 113, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_avg_pool                 │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_head_1 (Dense)               │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,780,739 (56.38 MB)
#  Trainable params: 66,051 (258.01 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ### Required before training
#
# VGG16 specific preprocessing layer into our model. The cleaneste way is to add the first step of our final model.

# %%
# VGG16 has a specific preprocessing function that needs 0-255 scaled input
vgg_preprocess = tf.keras.applications.vgg16.preprocess_input

# Apply this to the batched data. Since our `train_set`currently outputs 0-1, we need to rescale back to 0-255 first.

# The new input data should be:
# `vgg_preprocess(train_image_batch * 255.0)`

# %% [markdown]
# ## 🧠 Model Prototyping: VGG16 Transfer Learning Shell

# %% [markdown]
# ### 1. The VGG16 Transfer Learning Model Definition
# The model is defined exactly as in the previous step, including loading the base, freezing it, and attaching your custom 3-class classification head.

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# --- Constants ---
TARGET_INPUT_SHAPE = (227, 227, 3)
N_CLASSES = 3

def build_vgg16_transfer_model():
    # 1. Load the pre-trained VGG16 base model
    vgg16_base = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=TARGET_INPUT_SHAPE
    )

    # 2. Freeze the base layers (Transfer Learning Core Principle)
    for layer in vgg16_base.layers:
        layer.trainable = False

    # 3. Build the New Classification Head
    x = vgg16_base.output
    x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    x = Dense(128, activation='relu', name='fc_head_1')(x)
    x = Dropout(0.5, name='dropout_1')(x) # Regularization
    predictions = Dense(N_CLASSES, activation='softmax', name='predictions')(x)

    # 4. Create and Compile the Final Model
    model = Model(inputs=vgg16_base.input, outputs=predictions)

    # Use Nadam with an initial low learning rate (Transfer Learning Best Practice)
    model.compile(
        optimizer=Nadam(learning_rate=3e-3),
        loss='categorical_crossentropy', # For one-hot encoded labels
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# ### 2. Execution with Data Pipeline Integration
# Now, we need to integrate the create_dataset output (which is scaled $0-1$) and the class weights into the training call.Since VGG16 expects inputs scaled $0-255$ with specific centering, we'll use a wrapper function in the dataset map to perform the full ImageNet preprocessing, ensuring optimal transfer learning performance.

# %%
# Hardcoded Class Weights from Imbalance Analysis
CLASS_WEIGHTS = {
    0: 3.359,  # New Crater (ejecta)
    1: 2.025,  # Old Crater
    2: 0.453   # No Crater (none)
}

# %%
import tensorflow.keras.applications.vgg16
from tensorflow.keras import callbacks

# --- Data Transformation Helper ---
# VGG16 requires a specific preprocessing step (ImageNet mean subtraction).
# The current pipeline outputs 0-1 scaled images. We must rescale back to 0-255
# before applying VGG's complex preprocessing.
def vgg16_preprocessing_wrapper(image, label):
    # Rescale from 0-1 back to 0-255 (which VGG preprocess_input expects)
    image_255 = image * 255.0

    # Apply VGG's specific mean subtraction and scaling
    preprocessed_image = tf.keras.applications.vgg16.preprocess_input(image_255)

    return preprocessed_image, label


# --- Prepare Datasets for VGG16 ---

# Apply the VGG16-specific preprocessing to the *training set*
train_set_vgg = train_set.map(vgg16_preprocessing_wrapper,
                              num_parallel_calls=tf.data.AUTOTUNE)

# Apply the VGG16-specific preprocessing to the *validation set*
val_set_vgg = val_set.map(vgg16_preprocessing_wrapper,
                          num_parallel_calls=tf.data.AUTOTUNE)

# Apply the VGG16-specific preprocessing to the *test set*
test_set_vgg = test_set.map(vgg16_preprocessing_wrapper,
                            num_parallel_calls=tf.data.AUTOTUNE)


# --- Training Execution ---

# 1. Calculate Class Weights (Run this using the code from the previous coaching step!)
# class_weights = {0: 3.370, 1: 2.029, 2: 0.453} # Placeholder weights for visualization

# 2. Build the model
model = build_vgg16_transfer_model()

# 3. Define Early Stopping callback with patience
#early_stopping = callbacks.EarlyStopping(
#    monitor='val_loss',      # Monitor validation loss
#    patience=15,             # Number of epochs with no improvement after which training will be stopped
#    restore_best_weights=True,  # Restore the best weights when stopped
#    verbose=1                # Print message when stopping
#)

# Define multiple callbacks
early_stopping = [
    # Early stopping with patience
    callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    
    # Reduce learning rate on plateau
    callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,      # Reduce LR by half
        patience=5,      # Wait 5 epochs before reducing
        min_lr=1e-7,     # Minimum learning rate
        verbose=1
    ),
    
    # Model checkpoint to save best model (optional)
    callbacks.ModelCheckpoint(
        filepath='best_model.h5',
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=False,
        verbose=1
    )
]

# 4. Fit the model using the optimized datasets and class weights
history = model.fit(
    train_set_vgg,
    epochs=100, # Start with a few epochs to train the new head only
    steps_per_epoch=train_count // BATCH_SIZE,
    validation_data=val_set_vgg,
    validation_steps=val_count // BATCH_SIZE,
    class_weight=CLASS_WEIGHTS, # Use the weights calculated earlier!
    callbacks=early_stopping  # Add the callback here
)

print(f"\n--- Training Complete ---")
print(f"Best validation accuracy: {max(history.history['val_accuracy']):.4f}")
print(f"Stopped at epoch: {len(history.history['loss'])}")
# Out:
# Epoch 1/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5701 - loss: 1.2090
# Epoch 1: val_accuracy improved from -inf to 0.60197, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.5705 - loss: 1.2064 - val_accuracy: 0.6020 - val_loss: 0.9247 - learning_rate: 0.0030
# Epoch 2/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 13:17 4s/step - accuracy: 0.5000 - loss: 0.7405
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy improved from 0.60197 to 0.61020, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.5000 - loss: 0.7405 - val_accuracy: 0.6102 - val_loss: 0.8866 - learning_rate: 0.0030
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6764 - loss: 0.7386
# Epoch 3: val_accuracy improved from 0.61020 to 0.63816, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.6763 - loss: 0.7386 - val_accuracy: 0.6382 - val_loss: 0.8753 - learning_rate: 0.0030
# Epoch 4/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 1.1701
# Epoch 4: val_accuracy improved from 0.63816 to 0.64474, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6250 - loss: 1.1701 - val_accuracy: 0.6447 - val_loss: 0.8568 - learning_rate: 0.0030
# Epoch 5/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6605 - loss: 0.7269
# Epoch 5: val_accuracy did not improve from 0.64474
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.6604 - loss: 0.7269 - val_accuracy: 0.6398 - val_loss: 0.7346 - learning_rate: 0.0030
# Epoch 6/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 0.2533
# Epoch 6: val_accuracy improved from 0.64474 to 0.66118, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6250 - loss: 0.2533 - val_accuracy: 0.6612 - val_loss: 0.7079 - learning_rate: 0.0030
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6693 - loss: 0.6833
# Epoch 7: val_accuracy did not improve from 0.66118
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.6693 - loss: 0.6833 - val_accuracy: 0.5378 - val_loss: 1.0525 - learning_rate: 0.0030
# Epoch 8/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.3750 - loss: 2.1637
# Epoch 8: val_accuracy did not improve from 0.66118
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3750 - loss: 2.1637 - val_accuracy: 0.5773 - val_loss: 0.9296 - learning_rate: 0.0030
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6751 - loss: 0.6629
# Epoch 9: val_accuracy did not improve from 0.66118
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.6751 - loss: 0.6629 - val_accuracy: 0.6562 - val_loss: 0.8815 - learning_rate: 0.0030
# Epoch 10/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 0.6924
# Epoch 10: val_accuracy did not improve from 0.66118
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 0.6924 - val_accuracy: 0.6480 - val_loss: 0.8909 - learning_rate: 0.0030
# Epoch 11/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7036 - loss: 0.6148
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
#
# Epoch 11: val_accuracy did not improve from 0.66118
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7034 - loss: 0.6151 - val_accuracy: 0.5773 - val_loss: 0.9793 - learning_rate: 0.0030
# Epoch 12/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.7500 - loss: 0.6584
# Epoch 12: val_accuracy did not improve from 0.66118
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.6584 - val_accuracy: 0.5707 - val_loss: 0.9881 - learning_rate: 0.0015
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6782 - loss: 0.5876
# Epoch 13: val_accuracy improved from 0.66118 to 0.66283, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - accuracy: 0.6782 - loss: 0.5877 - val_accuracy: 0.6628 - val_loss: 0.7573 - learning_rate: 0.0015
# Epoch 14/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 0.9797
# Epoch 14: val_accuracy did not improve from 0.66283
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 0.9797 - val_accuracy: 0.6414 - val_loss: 0.7811 - learning_rate: 0.0015
# Epoch 15/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6945 - loss: 0.6095
# Epoch 15: val_accuracy improved from 0.66283 to 0.67928, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - accuracy: 0.6946 - loss: 0.6093 - val_accuracy: 0.6793 - val_loss: 0.7074 - learning_rate: 0.0015
# Epoch 16/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 0.6451
# Epoch 16: val_accuracy did not improve from 0.67928
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 0.6451 - val_accuracy: 0.6760 - val_loss: 0.7185 - learning_rate: 0.0015
# Epoch 17/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7387 - loss: 0.5218
# Epoch 17: val_accuracy did not improve from 0.67928
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7386 - loss: 0.5221 - val_accuracy: 0.6283 - val_loss: 0.7673 - learning_rate: 0.0015
# Epoch 18/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.7500 - loss: 0.2201
# Epoch 18: val_accuracy did not improve from 0.67928
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.2201 - val_accuracy: 0.6332 - val_loss: 0.7550 - learning_rate: 0.0015
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7506 - loss: 0.5035
# Epoch 19: val_accuracy did not improve from 0.67928
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7506 - loss: 0.5036 - val_accuracy: 0.5970 - val_loss: 0.8634 - learning_rate: 0.0015
# Epoch 20/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.5000 - loss: 0.5545
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
#
# Epoch 20: val_accuracy did not improve from 0.67928
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5000 - loss: 0.5545 - val_accuracy: 0.5970 - val_loss: 0.8833 - learning_rate: 0.0015
# Epoch 21/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7367 - loss: 0.4840
# Epoch 21: val_accuracy improved from 0.67928 to 0.68421, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - accuracy: 0.7367 - loss: 0.4841 - val_accuracy: 0.6842 - val_loss: 0.7044 - learning_rate: 7.5000e-04
# Epoch 22/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7500 - loss: 0.5591
# Epoch 22: val_accuracy did not improve from 0.68421
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.5591 - val_accuracy: 0.6727 - val_loss: 0.7104 - learning_rate: 7.5000e-04
# Epoch 23/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7525 - loss: 0.4791
# Epoch 23: val_accuracy did not improve from 0.68421
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7524 - loss: 0.4792 - val_accuracy: 0.6595 - val_loss: 0.7443 - learning_rate: 7.5000e-04
# Epoch 24/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 0.7083
# Epoch 24: val_accuracy did not improve from 0.68421
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 0.7083 - val_accuracy: 0.6562 - val_loss: 0.7536 - learning_rate: 7.5000e-04
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7465 - loss: 0.4910
# Epoch 25: val_accuracy improved from 0.68421 to 0.69079, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - accuracy: 0.7465 - loss: 0.4910 - val_accuracy: 0.6908 - val_loss: 0.6797 - learning_rate: 7.5000e-04
# Epoch 26/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8750 - loss: 0.2412
# Epoch 26: val_accuracy did not improve from 0.69079
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8750 - loss: 0.2412 - val_accuracy: 0.6875 - val_loss: 0.6815 - learning_rate: 7.5000e-04
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7672 - loss: 0.4648
# Epoch 27: val_accuracy improved from 0.69079 to 0.69243, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7672 - loss: 0.4648 - val_accuracy: 0.6924 - val_loss: 0.6929 - learning_rate: 7.5000e-04
# Epoch 28/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8750 - loss: 0.3823
# Epoch 28: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8750 - loss: 0.3823 - val_accuracy: 0.6859 - val_loss: 0.7093 - learning_rate: 7.5000e-04
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7726 - loss: 0.4153
# Epoch 29: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.7726 - loss: 0.4155 - val_accuracy: 0.6382 - val_loss: 0.7672 - learning_rate: 7.5000e-04
# Epoch 30/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7500 - loss: 0.2940
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.000375000003259629.
#
# Epoch 30: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.2940 - val_accuracy: 0.6414 - val_loss: 0.7640 - learning_rate: 7.5000e-04
# Epoch 31/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7750 - loss: 0.4332
# Epoch 31: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.7750 - loss: 0.4333 - val_accuracy: 0.6628 - val_loss: 0.7163 - learning_rate: 3.7500e-04
# Epoch 32/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7500 - loss: 0.8358
# Epoch 32: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.8358 - val_accuracy: 0.6612 - val_loss: 0.7222 - learning_rate: 3.7500e-04
# Epoch 33/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7737 - loss: 0.4052
# Epoch 33: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.7737 - loss: 0.4053 - val_accuracy: 0.6316 - val_loss: 0.7798 - learning_rate: 3.7500e-04
# Epoch 34/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 1.1153
# Epoch 34: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 1.1153 - val_accuracy: 0.6299 - val_loss: 0.7882 - learning_rate: 3.7500e-04
# Epoch 35/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7609 - loss: 0.4410
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001875000016298145.
#
# Epoch 35: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7610 - loss: 0.4409 - val_accuracy: 0.6793 - val_loss: 0.7042 - learning_rate: 3.7500e-04
# Epoch 36/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.6250 - loss: 0.9429
# Epoch 36: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 0.9429 - val_accuracy: 0.6793 - val_loss: 0.7037 - learning_rate: 1.8750e-04
# Epoch 37/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7775 - loss: 0.3983
# Epoch 37: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.7775 - loss: 0.3984 - val_accuracy: 0.6842 - val_loss: 0.6945 - learning_rate: 1.8750e-04
# Epoch 38/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8750 - loss: 0.3420
# Epoch 38: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8750 - loss: 0.3420 - val_accuracy: 0.6859 - val_loss: 0.6927 - learning_rate: 1.8750e-04
# Epoch 39/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8056 - loss: 0.3885
# Epoch 39: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.8054 - loss: 0.3887 - val_accuracy: 0.6727 - val_loss: 0.7224 - learning_rate: 1.8750e-04
# Epoch 40/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 1.0000 - loss: 0.1505
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.375000081490725e-05.
#
# Epoch 40: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 0.1505 - val_accuracy: 0.6727 - val_loss: 0.7227 - learning_rate: 1.8750e-04
# Epoch 41/100
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7832 - loss: 0.4049
# Epoch 41: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - accuracy: 0.7832 - loss: 0.4049 - val_accuracy: 0.6875 - val_loss: 0.6854 - learning_rate: 9.3750e-05
# Epoch 42/100
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8750 - loss: 0.6494
# Epoch 42: val_accuracy did not improve from 0.69243
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8750 - loss: 0.6494 - val_accuracy: 0.6859 - val_loss: 0.6847 - learning_rate: 9.3750e-05
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 27.
#
# --- Training Complete ---
# Best validation accuracy: 0.6924
# Stopped at epoch: 42

# %%
import pandas as pd
import matplotlib.pyplot as plt

# The 'history' object contains the training metrics for each epoch
history_df = pd.DataFrame(history.history)

# Plotting Loss and Accuracy over epochs
fig, axes = plt.subplots(1, 2, figsize=(15, 3))

# --- Plot 1: Loss Curves ---
history_df[['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('Loss Over Epochs')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Categorical Crossentropy Loss')
axes[0].grid(True)

# --- Plot 2: Accuracy Curves ---
history_df[['accuracy', 'val_accuracy']].plot(ax=axes[1])
axes[1].set_title('Accuracy Over Epochs')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].grid(True)

plt.tight_layout()
plt.show();

# %% [markdown]
# ## Metrics
# Since we have already trained the model (model) and have the final test_set ready, we can check some metrics.

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# --- Constants (Needed to map labels) ---
CLASS_NAMES = ["New Crater (0)", "Old Crater (1)", "No Crater (2)"]

# 1. Generate Predictions on the Test Set
print("Generating predictions on the test set...")
# Note: Use the test_set_vgg which has the correct VGG preprocessing applied
# test_set_vgg and test_count must be available from the previous steps.

# Create an iterable for the test set
test_data_iterable = test_set_vgg.unbatch().as_numpy_iterator()

# Extract images and true labels
y_true_list = []
x_test_list = []

for image, label in test_data_iterable:
    x_test_list.append(image)
    y_true_list.append(np.argmax(label)) # Convert one-hot to integer label

X_test_all = np.array(x_test_list)
y_true = np.array(y_true_list)

# Get predicted probabilities (softmax output)
y_proba = model.predict(test_set_vgg)

# Convert probabilities to hard integer predictions (class index with max proba)
y_pred = np.argmax(y_proba, axis=1)

# 2. Print Confusion Matrix
print("\n--- Confusion Matrix ---")
cm = confusion_matrix(y_true, y_pred)
print(cm)

# 3. Print Classification Report (Precision, Recall, F1-score)
print("\n--- Classification Report (Per-Class Metrics) ---")
report = classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=3)
print(report)
# Out:
# Generating predictions on the test set...
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
#
# --- Confusion Matrix ---
# [[ 64   6  19]
#  [ 10 120  27]
#  [ 68  64 401]]
#
# --- Classification Report (Per-Class Metrics) ---
#                 precision    recall  f1-score   support
#
# New Crater (0)      0.451     0.719     0.554        89
# Old Crater (1)      0.632     0.764     0.692       157
#  No Crater (2)      0.897     0.752     0.818       533
#
#       accuracy                          0.751       779
#      macro avg      0.660     0.745     0.688       779
#   weighted avg      0.793     0.751     0.763       779
